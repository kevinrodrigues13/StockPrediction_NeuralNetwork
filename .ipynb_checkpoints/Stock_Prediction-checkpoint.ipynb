# %%
import yfinance as yf
import pandas as pd
import numpy as np
#pull stock data
data = yf.download("AAPL", start="2014-01-01", end="2019-09-30")
#sample of stock data
data.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2014-01-02  79.38  79.58  78.86  79.02      71.32   58671200
# 2014-01-03  78.98  79.10  77.20  77.28      69.75   98116900
# 2014-01-06  76.78  78.11  76.23  77.70      70.13  103152700
# 2014-01-07  77.76  77.99  76.85  77.15      69.63   79302300
# 2014-01-08  76.97  77.94  76.96  77.64      70.07   64632400

# %%
from sklearn.preprocessing import MinMaxScaler
#Spliting data into train and test
#removing all rows if any of the feature is Nan
#Scaling using min-max
#removing features that are not needed
# data_train = data_train.drop('Close', 1)
def train_test(data):
    data.isna().any()
    sc = MinMaxScaler(feature_range = (0, 1))
    
    data_train = data.loc['2014-01-01':'2018-12-31']
    
    
    data_test = data.loc['2019-01-01':]
    
#     data_train_y = data_train['Close']
#     data_train = data_train.drop('Close', 1)
#     data_train = data_train.drop('Adj Close', 1)

    
#     data_train = sc.fit_transform(data_train)
# #     data_train_y = sc.fit_transform(data_train_y.values.reshape(1,-1))
#     data_test_y = data_test['Close']
#     data_test = data_test.drop('Close', 1)
# #     data_test = data_test.drop('Adj Close', 1)
#     data_test = sc.fit_transform(data_test)
# #     data_test_y = sc.fit_transform(data_test_y.values.reshape(1,-1))

    
# #     data_test = sc.fit_transform(data_test)

    training_set_scaled = sc.fit_transform(data_train)
    
    # Creating a data structure with 60 timesteps and 1 output for training
    X_train = []
    y_train = []
    for i in range(60, 1258):
        X_train.append(training_set_scaled[i-60:i, 3])
        y_train.append(training_set_scaled[i, 3])
    X_train, y_train = np.array(X_train), np.array(y_train)

    test_set_scaled = sc.fit_transform(data_test)
    
    # Creating a data structure with 60 timesteps and 1 output for testing
    X_test = []
    y_test = []
    for i in range(60, 180):
        X_test.append(test_set_scaled[i-60:i, 3])
        y_test.append(test_set_scaled[i, 3])
        
        
    X_train, y_train, X_test, y_test = np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

    
    return X_train, y_train, X_test, y_test, sc

# %%
X_train, y_train, X_test, y_test, sc = train_test(data)

# %%
print(X_train[0])
# Out:
# [0.0474264  0.03659675 0.0392108  0.03578764 0.03883737 0.03267567
#  0.02943922 0.0319288  0.04145142 0.05116076 0.04842223 0.03634779
#  0.04381652 0.0459949  0.05010269 0.04114023 0.04506131 0.00597498
#  0.00087135 0.         0.00068463 0.00155598 0.00796664 0.01138981
#  0.01132757 0.01767598 0.02595382 0.03217776 0.03211552 0.03970872
#  0.03927304 0.04107799 0.03342254 0.02788324 0.02265513 0.02464679
#  0.01979212 0.01562208 0.02477127 0.02352648 0.02483351 0.02794548
#  0.02894131 0.0275098  0.02726085 0.02769652 0.03224    0.03273791
#  0.02744756 0.02215722 0.02396216 0.02806996 0.02794548 0.02570486
#  0.02937698 0.03504077 0.04020663 0.03553868 0.03348478 0.03292463]

# %%
print(y_train)
# Out:
# [0.03286239 0.03721914 0.03802826 ... 0.52747868 0.5279766  0.53737474]

# %%
#creating basic MLP using TensorFlow

import tensorflow as tf

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(59, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation=tf.nn.relu))

model.compile(optimizer='adagrad', loss="mean_squared_error")

# %%
#fitting the model
model.fit(X_train,y_train,epochs = 100)
# Out:
# Train on 1198 samples
# Epoch 1/100
# 1198/1198 [==============================] - 1s 606us/sample - loss: 0.0069
# Epoch 2/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 0.0012
# Epoch 3/100
# 1198/1198 [==============================] - 0s 55us/sample - loss: 8.1259e-04
# Epoch 4/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 7.8722e-04
# Epoch 5/100
# 1198/1198 [==============================] - 0s 53us/sample - loss: 7.3880e-04
# Epoch 6/100
# 1198/1198 [==============================] - 0s 60us/sample - loss: 6.2595e-04
# Epoch 7/100
# 1198/1198 [==============================] - 0s 59us/sample - loss: 5.8757e-04
# Epoch 8/100
# 1198/1198 [==============================] - 0s 53us/sample - loss: 6.2272e-04
# Epoch 9/100
# 1198/1198 [==============================] - 0s 57us/sample - loss: 5.6967e-04
# Epoch 10/100
# 1198/1198 [==============================] - 0s 49us/sample - loss: 5.3711e-04
# Epoch 11/100
# 1198/1198 [==============================] - 0s 51us/sample - loss: 5.0477e-04
# Epoch 12/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 4.7443e-04
# Epoch 13/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 5.0144e-04
# Epoch 14/100
# 1198/1198 [==============================] - 0s 51us/sample - loss: 4.3608e-04
# Epoch 15/100
# 1198/1198 [==============================] - 0s 51us/sample - loss: 4.4901e-04
# Epoch 16/100
# 1198/1198 [==============================] - 0s 55us/sample - loss: 4.6739e-04
# Epoch 17/100
# 1198/1198 [==============================] - 0s 64us/sample - loss: 4.1839e-04
# Epoch 18/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 3.9828e-04
# Epoch 19/100
# 1198/1198 [==============================] - 0s 51us/sample - loss: 4.2950e-04
# Epoch 20/100
# 1198/1198 [==============================] - 0s 50us/sample - loss: 4.1051e-04
# Epoch 21/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 3.9040e-04
# Epoch 22/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 4.2007e-04
# Epoch 23/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 3.9798e-04
# Epoch 24/100
# 1198/1198 [==============================] - 0s 62us/sample - loss: 4.0444e-04
# 1198/1198 [==============================] - 0s 54us/sample - loss: 2.8811e-04
# Epoch 90/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 2.8922e-04
# Epoch 91/100
# 1198/1198 [==============================] - 0s 58us/sample - loss: 2.8983e-04
# Epoch 92/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 2.8559e-04
# Epoch 93/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 2.8089e-04
# Epoch 94/100
# 1198/1198 [==============================] - 0s 54us/sample - loss: 2.7839e-04
# Epoch 95/100
# 1198/1198 [==============================] - 0s 51us/sample - loss: 2.8698e-04
# Epoch 96/100
# 1198/1198 [==============================] - 0s 61us/sample - loss: 2.7970e-04
# Epoch 97/100
# 1198/1198 [==============================] - 0s 65us/sample - loss: 2.8804e-04
# Epoch 98/100
# 1198/1198 [==============================] - 0s 52us/sample - loss: 2.9339e-04
# Epoch 99/100
# 1198/1198 [==============================] - 0s 53us/sample - loss: 2.7930e-04
# Epoch 100/100
# 1198/1198 [==============================] - 0s 58us/sample - loss: 2.7815e-04

# %%
#model evaluation based on loss
model.evaluate(X_test, y_test )
y_pred = model.predict(X_test)
# Out:
# 120/1 [================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 537us/sample - loss: 0.0060

# %%
#Plotting pedicted vs actual price to see if trend is captured
import matplotlib.pyplot as plt

plt.plot(y_test, color = 'red', label = 'Real Apple Stock Price')
plt.plot(y_pred, color = 'blue', label = 'Predicted  Apple Price')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()

# %%
# model1 = tf.keras.Sequential()
# model1.add(tf.keras.layers.LSTM(20, input_shape=(data_train.shape[1], 1), return_sequences=True))
# model1.add(tf.keras.layers.LSTM(20))
# model1.add(tf.keras.layers.Dense(1, activation=tf.nn.relu))
# model1.add(tf.keras.layers.Dense(1, activation=tf.nn.relu))



# model1.compile(optimizer="adam", loss="mean_squared_error")

# model1.input_shape



# Initialising the RNN
regressor = tf.keras.Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding a fifth LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding a sixth LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50))
regressor.add(tf.keras.layers.Dropout(0.5))

# Adding the output layer
regressor.add(tf.keras.layers.Dense(units = 1))


# Compiling the RNN
regressor.compile(optimizer = 'adagrad', loss = 'mean_squared_error')

# %%
X_train_re = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor.fit(X_train_re, y_train, epochs=100,batch_size = 32)
# Out:
# Train on 1198 samples
# Epoch 1/100
# 1198/1198 [==============================] - 16s 13ms/sample - loss: 0.0361
# Epoch 2/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0150
# Epoch 3/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0152
# Epoch 4/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0132
# Epoch 5/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0135
# Epoch 6/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0123
# Epoch 7/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0131
# Epoch 8/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0122
# Epoch 9/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0111
# Epoch 10/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0115
# Epoch 11/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0107
# Epoch 12/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0117
# Epoch 13/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0116
# Epoch 14/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0116
# Epoch 15/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0113
# Epoch 16/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0121
# Epoch 17/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0095
# Epoch 18/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0112
# Epoch 19/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0100
# Epoch 20/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0099
# Epoch 21/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0107
# Epoch 22/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0112
# Epoch 23/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0101
# Epoch 24/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0109
# Epoch 25/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0104
# Epoch 26/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0097
# Epoch 27/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0097
# Epoch 28/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0109
# Epoch 29/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0098
# Epoch 30/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0093
# Epoch 31/100
# 1198/1198 [==============================] - 8s 6ms/sample - loss: 0.0099
# Epoch 32/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0094
# Epoch 33/100
# 1198/1198 [==============================] - 7s 5ms/sample - loss: 0.0096
# Epoch 34/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0091
# Epoch 35/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0102
# Epoch 36/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0096
# Epoch 37/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0088
# Epoch 38/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0105
# Epoch 39/100
# 1198/1198 [==============================] - 14s 12ms/sample - loss: 0.0094
# Epoch 40/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0090
# Epoch 41/100
# 1198/1198 [==============================] - 9s 8ms/sample - loss: 0.0085
# Epoch 42/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0096
# Epoch 43/100
# 1198/1198 [==============================] - 8s 6ms/sample - loss: 0.0096
# Epoch 44/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0092
# Epoch 45/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0102
# Epoch 46/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0095
# Epoch 47/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 48/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0098
# Epoch 49/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0097
# Epoch 50/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 51/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0091
# Epoch 52/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0090
# Epoch 53/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0083
# Epoch 54/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0090
# Epoch 55/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0095
# Epoch 56/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0093
# Epoch 57/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0082
# Epoch 58/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 59/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0092
# Epoch 60/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0083
# Epoch 61/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0095
# Epoch 62/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 63/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0092
# Epoch 64/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0090
# Epoch 65/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0077
# Epoch 66/100
# 1198/1198 [==============================] - 8s 6ms/sample - loss: 0.0082
# Epoch 67/100
# 1198/1198 [==============================] - 7s 5ms/sample - loss: 0.0082
# Epoch 68/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0092
# Epoch 69/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0084
# Epoch 70/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0091
# Epoch 71/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0091
# Epoch 72/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0080
# Epoch 73/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 74/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0079
# Epoch 75/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0083
# Epoch 76/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0088
# Epoch 77/100
# 1198/1198 [==============================] - 5s 5ms/sample - loss: 0.0081
# Epoch 78/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0093
# Epoch 79/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0083
# Epoch 80/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0080
# Epoch 81/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0074
# Epoch 82/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0086
# Epoch 83/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0076
# Epoch 84/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0080
# Epoch 85/100
# 1198/1198 [==============================] - 8s 6ms/sample - loss: 0.0080
# Epoch 86/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0084
# Epoch 87/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0092
# Epoch 88/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0075
# Epoch 89/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0081
# Epoch 90/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0086
# Epoch 91/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0078
# Epoch 92/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0084
# Epoch 93/100
# 1198/1198 [==============================] - 7s 6ms/sample - loss: 0.0082
# Epoch 94/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0079
# Epoch 95/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0074
# Epoch 96/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0081
# Epoch 97/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0081
# Epoch 98/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0083
# Epoch 99/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0074
# Epoch 100/100
# 1198/1198 [==============================] - 6s 5ms/sample - loss: 0.0073

# %%
X_test_re = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
regressor.evaluate(X_test_re, y_test)
# print(sc)
yY_pred = regressor.predict(X_test_re)
# yY_pred = sc.inverse_transform(yY_pred)
# y_pred = sc.inverse_transform(y_pred)
# y_test = sc.inverse_transform(y_test)
# Out:
# 120/1 [================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 4s 31ms/sample - loss: 0.0197

# %%
#Plotting predicted vs actual price to see if trend is captured

import matplotlib.pyplot as plt

plt.plot(y_test, color = 'red', label = 'Real Apple Stock Price')
plt.plot(y_pred, color = 'black', label = 'Predicted  Apple Price MPL')
plt.plot(yY_pred, color = 'yellow', label = 'Predicted  Apple Price RNN')

plt.title('Apple Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()
